# %%
import matplotlib.pyplot as plt

import os, sys

parent = os.path.abspath("../..")

if not parent in sys.path:
    sys.path.append(parent)

from src.utilities import *
from src.pairings import *
from src.majority_judgment.majority_judgment import *

# %%
N = 500
budget = 20_000

# %%
L1 = [MajorityJudgement(N, budget, spread=1).score() for _ in range(20)]
L2 = [MajorityJudgement(N, budget, spread=2).score() for _ in range(20)]

# %%
fig, axes = plt.subplots(1, 2, sharey=True)
fig.suptitle('Majority Judgement benchmarks')

axes[0].boxplot(L1)
axes[0].set_title('sigma=1')

axes[1].boxplot(L2)
axes[1].set_title('sigma=2')

for ax in axes:
  ax.get_xaxis().set_visible(False)
