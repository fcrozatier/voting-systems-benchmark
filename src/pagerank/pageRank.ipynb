# %%
import matplotlib.pyplot as plt

plt.style.use('_mpl-gallery')

import os, sys
parent = os.path.abspath('../..')

if not parent in sys.path: sys.path.append(parent)

from src.utilities import *
from src.pairings import *
from src.pagerank.pagerank import *

# %%
N = 500
budget = range(1000, 20000, 1000)

# %%
L = [PageRank(Random(N), b, rematch=1, p=1).score() for b in budget]

plt.plot(list(budget), L)
plt.show()

# %%
L = [PageRank(RandomCycles(N), b, rematch=1, p=1).score() for b in budget]

plt.plot(list(budget), L)
plt.show()

# %%
L = [PageRank(CCZip(N), b, rematch=1, p=0.999).score() for b in budget]

plt.plot(list(budget), L)
plt.show()

# %%
L = [PageRank(Reachability(N), b, rematch=1, p=0.999).score() for b in range(1000, 20000, 4000)]
# SLOW (1h10min)

# %%
plt.plot([1,5,9,13,17],L)
plt.show()

# %%
PageRank(Reachability(N), 5000, rematch=1, p=1).score()
# Out:
# 0.31999999999999995
