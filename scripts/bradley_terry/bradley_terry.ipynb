# %%
import matplotlib.pyplot as plt

plt.style.use('_mpl-gallery')

import os, sys
parent = os.path.abspath('../..')

if not parent in sys.path: sys.path.append(parent)

from scripts.bradley_terry.bradley_terry import *
from scripts.utilities import *

# %%
N = 500
ranking = random_ranking(N)

# %%
budget = range(1000, 10000, 1000)
L = [top_10(ranking, BT(ranking, b, 5, 0.7)) for b in budget]

plt.plot(list(budget), L)
plt.show()
