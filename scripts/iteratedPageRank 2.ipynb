# %%
from utilities import *
import matplotlib.pyplot as plt
from votes import *

plt.style.use('_mpl-gallery')

# %%
N = 1000
ranking = random_ranking(N)

# %%
R = range(5000, 30000, 1000)
L = [top_10(ranking, iteratedPageRank(ranking, b, 1, 0.9)) for b in R]

plt.plot(list(R), L)
plt.show()
